# %%
import pandas as pd

# %%
df = pd.read_csv('data_sf.csv.xls')

# %%
df_5kk = df.groupby('Position')['Wage'].sum().sort_values(ascending=False)

# %%
df_5kk.head(9)
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# Name: Wage, dtype: int64

# %%
df_5kk
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# RCB     4711000
# LCB     3989000
# RW      3276000
# RCM     3241000
# LCM     3145000
# LW      2945000
# LS      1866000
# RDM     1557000
# RS      1537000
# LDM     1516000
# RF       714000
# LF       601000
# RWB      420000
# LAM      366000
# LWB      347000
# CF       248000
# RAM       59000
# Name: Wage, dtype: int64

# %%
df_tst = df.groupby(['Position'])[['Wage','Value']].mean().sort_values(['Value'],ascending=False)

# %%
df_tst
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %% [markdown]
# Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club). В скольких клубах средняя и медианная зарплаты совпадают?
#
# Подсказка: чтобы в процессе группировки применить к данным одновременно две агрегирующие функции, необходимо указать их как аргументы метода agg:
#
# df.groupby(столбец_для_группировки)[столбцы_для_отображения].agg(['функция_1', 'функция_2'])

# %%
asr = df.groupby(['Club'])['Wage'].agg()

# %%
df_tst2 = df.groupby(['Club'])['Wage'].agg([lambda x: x.mean(),lambda x: x.median()])

# %%
#df_tst2[df_tst2.index[1]==df_tst2.index[2]]

# %%
df_tst2[df_tst2['<lambda_0>']==df_tst2['<lambda_1>']].sort_values(['<lambda_0>'],ascending=False)
# Out:
#                         <lambda_0>  <lambda_1>
# Club
# Cruzeiro                   13000.0       13000
# Göztepe SK                  7000.0        7000
# Brøndby IF                  6000.0        6000
# Sunderland                  4000.0        4000
# CD Feirense                 4000.0        4000
# 1. FC Magdeburg             4000.0        4000
# Northampton Town            2500.0        2500
# Stade Brestois 29           2000.0        2000
# Jeonnam Dragons             2000.0        2000
# Pohang Steelers             2000.0        2000
# AJ Auxerre                  2000.0        2000
# Grimsby Town                2000.0        2000
# Heracles Almelo             2000.0        2000
# Philadelphia Union          2000.0        2000
# Kashiwa Reysol              2000.0        2000
# CD Tondela                  2000.0        2000
# Benevento                   2000.0        2000
# FC Metz                     1500.0        1500
# PAOK                        1000.0        1000
# ...

# %%
df_Chelsea = df[df['Club']=='Chelsea'].groupby(['Club'])['Wage'].sum()

# %%
df_Chelsea
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %%
df_Argentina = df[(df['Nationality']=='Argentina')&(df['Age']==20)]['Wage'].max()

# %%
df_Argentina
# Out:
# 54000

# %%
df_Arg2 = df[(df['Age']==30)&(df['Nationality']=='Argentina')].groupby(['Nationality','Age'])['Wage'].min()

# %%
df_Arg2
# Out:
# Nationality  Age
# Argentina    30     1000
# Name: Wage, dtype: int64

# %%
df_last = df[(df['Club']=='FC Barcelona')]

# %% [markdown]
# Определите максимальную силу (Strength) и баланс (Balance) среди игроков клуба (Club) "FC Barcelona" из Аргентины ("Argentina"). Ответ введите через точку с запятой без пробела.

# %%
df_last = df[(df['Club']=='FC Barcelona')&(df['Nationality']!='Argentina')][['Strength','Balance']].groupby(['Club'],['Nationality']).max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-baacab900444> in <module>
# ----> 1 df_last = df[(df['Club']=='FC Barcelona')&(df['Nationality']!='Argentina')][['Strength','Balance']].groupby(['Club'],['Nationality']).max()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7881         if level is None and by is None:
#    7882             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7883         axis = self._get_axis_number(axis)
#    7884         return groupby(
#    7885             self,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     400     @classmethod
#     401     def _get_axis_number(cls, axis):
# --> 402         axis = cls._AXIS_ALIASES.get(axis, axis)
# ...

# %%
df_last
# Out:
#       Strength  Balance
# 7           83       83
# 18          79       43
# 20          77       52
# 32          61       93
# 42          84       66
# 49          61       85
# 53          66       66
# 54          83       36
# 96          79       75
# 141         46       85
# 190         62       86
# 195         80       60
# 204         67       50
# 235         62       83
# 605         79       56
# 1464        63       75
# 5377        67       61
# 5613        60       64
# 6124        51       75
# 7312        64       45
# 9028        54       51

# %%
df_last2 = df[(df['Nationality']=='Argentina')&(df['Club']=='FC Barcelona')].groupby(['Club','Nationality']).max()[['Strength','Balance']]
df_last2
# Out:
#                           Strength  Balance
# Club         Nationality
# FC Barcelona Argentina          59       95

# %%
df_last2
# Out:
#                        Unnamed: 0         Name  Age    Nationality     Value  \
# Club
#  SSV Jahn Regensburg        12711    S. Stolze   33         Poland    950000
# 1. FC Heidenheim 1846       12465    V. Eicher   32        Germany   5000000
# 1. FC Kaiserslautern        12451      W. Hesl   33         Turkey    900000
# 1. FC Köln                  12605   Y. Bisseck   35  United States  24000000
# 1. FC Magdeburg             11622    T. Müller   32         Kosovo  45000000
# ...                           ...          ...  ...            ...       ...
# Zagłębie Sosnowiec          12922  Z. Udovičić   36       Slovenia    675000
# Çaykur Rizespor             11938       S. Koç   34         Turkey   7000000
# Örebro SK                   13085  V. Tranberg   34          Syria    725000
# Östersunds FK               12950     T. Tekie   31         Sweden    975000
# Śląsk Wrocław               12493     W. Golla   35       Slovakia   1000000
#
# ...
